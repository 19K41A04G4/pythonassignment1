# %%
#Question 1
print(0.1+0.2)
print("1.8"+"2")
print(87>78)
print((0.1+0.2)==0.3)
print("Predict ""Outpot" ,".....")
# Out:
# 0.30000000000000004
# 1.82
# True
# False
# Predict Outpot .....

# %%
#Question 2
print("Prints","multiple ","messages\n")
print("concatenate "+" two strings\n")
print(5+6+" adds two numbers\n")
# Out:
# Prints multiple  messages
#
# concatenate  two strings
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-3219980ed451> in <module>()
#       1 print("Prints","multiple ","messages\n")
#       2 print("concatenate "+" two strings\n")
# ----> 3 print(5+6+" adds two numbers\n")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Question 3
print("ba"+"na"*2)
print(r"C:\naresh\raju\abhi")
# Out:
# banana
# C:\naresh\raju\abhi

# %%
#Question 4
print('Welcome to Python traing program'[28:-40:-4])
print('A series of characters designated as one object known as a string'[2:18:5])
# Out:
# g anytoW
# sscc

# %%
#Question 5
print('A series of characters designated as one object known as a string'[::-1][4::3])
print("-----------")
print('Welcome to Python traing program'[3:10][::-1])
# Out:
# taawkcbe  tgestrcoeeA
# -----------
# ot emoc

# %%
#Question 6.a
2str1=True
x= 5> 3
print(str1==x)
y= 5 > 8
print(str1==y)
# Out:
# True
# False

# %%
#Question 6.b
num=7
Name = "michael Jackson"
sear_num = Name.find('el')
print(num > sear_num )
# Out:
# True

# %%
#Question 7
p_phrase="was it a car or a cat I saw"[27::-1]
p_phrase.upper()
# Out:
# 'WAS I TAC A RO RAC A TI SAW'

# %%
#Question 8
A='1934567'
A[1::2]
# Out:
# '946'

# %%
#Question 9
fake_phrase=" Fake news has a knack for spreading like wildfire"[-10:15:-1]
fake_phrase.upper().split()
# Out:
# ['EKIL', 'GNIDAERPS', 'ROF', 'KCANK']

# %%
#Question 10
msg1="Facebook already uses AI to Filter Fake stories from the feeds of users"
print(msg1.split())
# Out:
# ['Facebook', 'already', 'uses', 'AI', 'to', 'Filter', 'Fake', 'stories', 'from', 'the', 'feeds', 'of', 'users']

# %%
#Question 11
msg2="Welcome to sr engineering college"
x=msg2.count('o')
y=msg2.count('r')
print(x)
print(y)
#here the count(element) command counts the number of repetations of the element specified within the brackets.
msg2[y**x:(x**y+x+y):][::-1]
#In the above line the x and y values are taken from the lines mentioed before in this program.In the first square bracket ,1st element indicates lower boundary,that is 9th position.2nd elemnts indicated the upper boundary, that is 14th position.and next square bracket indicates the reverse order of the string.
# Out:
# 3
# 2
# ' rs ot'

# %%
#Question 12.a
num1,num2="94","30"
data="As per Census 2011, Gender ratio of India is 943 females per 1000 males"
num1+num2[0] in data
#addition of num1 and num2 doesnt indicates the addition of numbers,instead it tells to place the 2 strings side by side and the + sign indicates the space.Since 94 from num1 and 3 from num2 combines and form 943.The last line tells the compiler tho find whether 943 is present in the giving string or not.
# Out:
# True

# %%
#Question 12.b
print(data[:45],print(int(num1)+int(num2)))
#Here 1st the num1 and num2 will be converted into integers and added to each other.Then from 1st element of the string to 44th element it gets printed.At last none is printed because there is no return value for the print(int(num1)+int(num2)) function
# Out:
# 124
# As per Census 2011, Gender ratio of India is  None

# %%
#Question 13
M=float(input('Amount of Water in kgs'))
initial=float(input('Initial Temperature in degree celsius'))
final=float(input('Final Temperature in degree celsius'))
Q=4184*M*(final-initial)
print(f'The energy required to heat water from an Initial to Final temperature is {Q} joules')
# Out:
# Amount of Water in kgs100
# Initial Temperature in degree celsius30
# Final Temperature in degree celsius130
# The energy required to heat water from an Initial to Final temperature is 41840000.0 joules

# %%
#Question 14
x=int(input('X'))
y=x*2
print(f"The generated word is : {'z'*x+'o'*y}")
# Out:
# X3
# The generated word is : zzzoooooo

# %%
#Question 15
x=int(input('X'))
y=int(input('Y'))
pow=x**y
print(pow)
div=int(pow/(x*y))
print(div)
print(div^(x+y))
# Out:
# X6
# Y9
# 10077696
# 186624
# 186639
